# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.3 MB/s
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.8/dist-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from geopandas) (21.3)
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 38.2 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      |████████████████████████████████| 16.6 MB 80 kB/s
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->geopandas) (3.0.9)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1

# %%
import pandas as pd
import geopandas as gpd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# !pip install --upgrade botocore==1.23.26  #Sur colab, sinon bug
# !pip install --upgrade urllib3==1.22.0 #Sur colab, sinon bug
# !pip install py7zr #Sur colab, sinon bug
# !pip install s3fs #Sur colab, sinon bug
# !git clone https://github.com/InseeFrLab/cartogether.git
# %cd ./cartogether
# !pip install -r requirements.txt
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting botocore==1.23.26
#   Downloading botocore-1.23.26-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 126 kB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 40.2 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore==1.23.26) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.23.26) (1.15.0)
# Installing collected packages: urllib3, jmespath, botocore
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.13 which is incompatible.
# Successfully installed botocore-1.23.26 jmespath-0.10.0 urllib3-1.26.13
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting urllib3==1.22.0
#   Downloading urllib3-1.22-py2.py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 4.7 MB/s
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.13
#     Uninstalling urllib3-1.26.13:
#       Successfully uninstalled urllib3-1.26.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.23.26 requires urllib3<1.27,>=1.25.4, but you have urllib3 1.22 which is incompatible.
# Successfully installed urllib3-1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting py7zr
#   Downloading py7zr-0.20.2-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.3 MB/s
# Collecting pyppmd<1.1.0,>=0.18.1
#   Downloading pyppmd-1.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      |████████████████████████████████| 139 kB 9.5 MB/s
# Collecting pyzstd>=0.14.4
#   Downloading pyzstd-0.15.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (378 kB)
#      |████████████████████████████████| 378 kB 51.2 MB/s
# Collecting inflate64>=0.3.1
#   Downloading inflate64-0.3.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Collecting pybcj>=0.6.0
#   Downloading pybcj-1.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 3.2 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from py7zr) (5.4.8)
# Collecting multivolumefile>=0.2.3
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting pycryptodomex>=3.6.6
#   Downloading pycryptodomex-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 65.4 MB/s
# Collecting texttable
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Collecting brotli>=1.0.9
#   Downloading Brotli-1.0.9-cp38-cp38-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 51.1 MB/s
# Installing collected packages: texttable, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, brotli, py7zr
# Successfully installed brotli-1.0.9 inflate64-0.3.1 multivolumefile-0.2.3 py7zr-0.20.2 pybcj-1.0.1 pycryptodomex-3.16.0 pyppmd-1.0.0 pyzstd-0.15.3 texttable-1.6.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting s3fs
#   Downloading s3fs-2022.11.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from s3fs) (3.8.3)
# Collecting aiobotocore~=2.4.0
#   Downloading aiobotocore-2.4.1-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 3.0 MB/s
# Requirement already satisfied: fsspec==2022.11.0 in /usr/local/lib/python3.8/dist-packages (from s3fs) (2022.11.0)
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Collecting botocore<1.27.60,>=1.27.59
#   Downloading botocore-1.27.59-py3-none-any.whl (9.1 MB)
#      |████████████████████████████████| 9.1 MB 32.0 MB/s
# Requirement already satisfied: wrapt>=1.10.10 in /usr/local/lib/python3.8/dist-packages (from aiobotocore~=2.4.0->s3fs) (1.14.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.8.2)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.8/dist-packages (from aioitertools>=0.5.1->aiobotocore~=2.4.0->s3fs) (4.4.0)
# Collecting urllib3<1.27,>=1.25.4
#   Using cached urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.0->s3fs) (2.8.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.0->s3fs) (0.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.0->s3fs) (1.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.10)
# Installing collected packages: urllib3, botocore, aioitertools, aiobotocore, s3fs
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.22
#     Uninstalling urllib3-1.22:
#       Successfully uninstalled urllib3-1.22
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.23.26
#     Uninstalling botocore-1.23.26:
#       Successfully uninstalled botocore-1.23.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.13 which is incompatible.
# Successfully installed aiobotocore-2.4.1 aioitertools-0.11.0 botocore-1.27.59 s3fs-2022.11.0 urllib3-1.26.13
# Cloning into 'cartogether'...
# remote: Enumerating objects: 309, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 309 (delta 93), reused 131 (delta 53), pack-reused 104
# Receiving objects: 100% (309/309), 3.96 MiB | 19.97 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# /content/cartogether
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: py7zr in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 2)) (0.20.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 3)) (0.12.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 4)) (3.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 5)) (4.64.1)
# Requirement already satisfied: s3fs in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 6)) (2022.11.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 7)) (6.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->-r requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->-r requirements.txt (line 1)) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 4.9 MB/s
# Requirement already satisfied: brotli>=1.0.9 in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (5.4.8)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (3.16.0)
# Requirement already satisfied: pybcj>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: inflate64>=0.3.1 in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: texttable in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (1.6.7)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: pyzstd>=0.14.4 in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (0.15.3)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.8/dist-packages (from py7zr->-r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from geopandas->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.8/dist-packages (from geopandas->-r requirements.txt (line 3)) (1.8.22)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.8/dist-packages (from geopandas->-r requirements.txt (line 3)) (1.8.5.post1)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /usr/local/lib/python3.8/dist-packages (from geopandas->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from geopandas->-r requirements.txt (line 3)) (1.3.5)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 3)) (57.4.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas->-r requirements.txt (line 3)) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas->-r requirements.txt (line 3)) (1.21.6)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: aiobotocore~=2.4.0 in /usr/local/lib/python3.8/dist-packages (from s3fs->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: fsspec==2022.11.0 in /usr/local/lib/python3.8/dist-packages (from s3fs->-r requirements.txt (line 6)) (2022.11.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from s3fs->-r requirements.txt (line 6)) (3.8.3)
# Requirement already satisfied: wrapt>=1.10.10 in /usr/local/lib/python3.8/dist-packages (from aiobotocore~=2.4.0->s3fs->-r requirements.txt (line 6)) (1.14.1)
# Requirement already satisfied: botocore<1.27.60,>=1.27.59 in /usr/local/lib/python3.8/dist-packages (from aiobotocore~=2.4.0->s3fs->-r requirements.txt (line 6)) (1.27.59)
# Requirement already satisfied: aioitertools>=0.5.1 in /usr/local/lib/python3.8/dist-packages (from aiobotocore~=2.4.0->s3fs->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 6)) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.8/dist-packages (from aioitertools>=0.5.1->aiobotocore~=2.4.0->s3fs->-r requirements.txt (line 6)) (4.4.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.0->s3fs->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->geopandas->-r requirements.txt (line 3)) (3.0.9)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.13
#     Uninstalling urllib3-1.26.13:
#       Successfully uninstalled urllib3-1.26.13
# Successfully installed urllib3-1.25.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/cartogether
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: UNKNOWN
#   Building wheel for UNKNOWN (PEP 517) ... done
#   Created wheel for UNKNOWN: filename=UNKNOWN-0.0.0-py3-none-any.whl size=19403 sha256=47a8e813c3a923060a9178cf642ffd684dd6b4d974f8960eb84fb9ed6ca0892b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zxws58x2/wheels/11/92/b5/0f71113bd905576454a9db56800f030231c1da374f630f8901
# Successfully built UNKNOWN
# Installing collected packages: UNKNOWN
# Successfully installed UNKNOWN-0.0.0

# %%
import cartiflette.s3

# %%
df_secheresse=gpd.read_file("/content/AleaRG01_L93.shp")

# %%
#Fonction geometry (de l'habitation) ->risque 
def risque(geometry):
  risque=[]
  for k in range(len(df_secheresse["geometry"])):
    if df_secheresse["geometry"][k].contains(geometry):
      risque.append(df_secheresse["alea"][k])
  
  return(risque)
